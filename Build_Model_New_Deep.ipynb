# %% [markdown]
# # Build model — NEW aggregator (DEEP tree)
#
# Same data/flow as `Build_Model_New.ipynb`, but with a **deeper, less-regularized XGBoost**.
#
# **Why:** the lightweight tree (depth 3, `colsample_bytree=0.05`, `min_child_weight=250`) is so throttled it
# leans on the unchanged delinquency *count* features and never has to use the `percent_of_DQ` features the
# aggregator fix actually moves. A deeper, feature-hungrier tree gives the fix a chance to show up if it can.
#
# - **trade** = `Features_To_Use.json` subset (the percent-of-DQ features), **app** = all cols, **target** = `final_DQ60_m24`
# - train Q2'19, evaluate test rows via `data_split`
# - LevelSelection -> FillNA -> XGBoost (**depth 8, n_estimators 800, colsample 0.3, min_child_weight 50**)
#
# Output -> `payment_processing_research_data/models/model_new_deep/` (originals untouched). Model-engine kernel.

# %%
# %pip install "setuptools<81"
# Out:
# Looking in indexes: http://zamlpkgs-nginx/artifactory/api/pypi/zest_pypi/simple/
# Collecting setuptools<81
#   Downloading http://zamlpkgs-nginx/artifactory/api/pypi/zest_pypi/packages/packages/94/b8/f1f62a5e3c0ad2ff1d189590bfa4c46b4f3b6e49cef6f26c6ee4e575394d/setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.2 MB/s  0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.0
#     Uninstalling setuptools-82.0.0:
#       Successfully uninstalled setuptools-82.0.0
# Successfully installed setuptools-80.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, json, importlib
import model_configs
from model_engine.model_builder.build_model import build_model

VARIANT = 'new'
out_dir = os.path.join(model_configs.MODELS_DIR, f'model_{VARIANT}_deep')
os.makedirs(out_dir, exist_ok=True)
print('variant:', VARIANT, '| DEEP | output ->', out_dir)
# Out:
# /home/jag/.conda/envs/model_engine_2_py310/lib/python3.10/site-packages/zaml/common/utils/io.py:17: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# WARNING:py.warnings:Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
# variant: new | DEEP | output -> /home/jag/payment-processor-research/payment_processing_research_data/models/model_new_deep

# %%
# Deeper, less-regularized pipeline (override the lightweight one in model_configs).
# Same LevelSelection -> FillNA front end; only the XGBoost knobs change.
DEEP_PIPELINE_FACTORY = {
    'transformers': [
        {'zaml_class': 'LevelSelection',
         'params': {'thresh': 0.01, 'change_to': 'Other', 'encoding': 'onehot'}},
        {'zaml_class': 'FillNA',
         'params': {'replace_by': -1, 'add_flags': False}},
    ],
    'model': {
        'zaml_class': 'XGBoostModel',
        'params': {
            'learning_rate':     0.03,
            'n_estimators':      800,
            'max_depth':         8,      # was 3
            'backend_subsample': 0.7,
            'scale_pos_weight':  2.5,
            'colsample_bytree':  0.30,   # was 0.05 -> trees can actually see the percent features
            'min_child_weight':  50,     # was 250 -> finer splits allowed
        },
    },
}

asset = model_configs.build_asset(VARIANT)
asset['config']['pipeline_factory'] = DEEP_PIPELINE_FACTORY
print('xgb params:', asset['config']['pipeline_factory']['model']['params'])
# Out:
# xgb params: {'learning_rate': 0.03, 'n_estimators': 800, 'max_depth': 8, 'backend_subsample': 0.7, 'scale_pos_weight': 2.5, 'colsample_bytree': 0.3, 'min_child_weight': 50}

# %%
# sanity: every table has files before we train
for tbl in ['app', 'trade', 'target']:
    n = len(asset['data'][tbl]['data'])
    print(f'{tbl:7}: {n} files')
    assert n > 0, f'no {tbl} files -- run the fix_processing/Sample_* notebooks first'
print('trade keep_features:', 'ALL' if asset['data']['trade']['io_params']['keep_features'] is None
      else len(asset['data']['trade']['io_params']['keep_features']))
print('data_split:', asset['config']['data_split'])

json.dump(asset, open(os.path.join(out_dir, 'asset.json'), 'w'), indent=2)
print('wrote', os.path.join(out_dir, 'asset.json'))
# Out:
# app    : 6 files
# trade  : 6 files
# target : 6 files
# trade keep_features: 1143
# data_split: {'train': {'start_date': '2019-04-01', 'end_date': '2019-07-01'}, 'test': {'start_date': '2019-07-01', 'end_date': '2020-04-01'}}
# wrote /home/jag/payment-processor-research/payment_processing_research_data/models/model_new_deep/asset.json

# %%
import logging, traceback

log_path = os.path.join(out_dir, f'build_model_{VARIANT}_deep.log')
fh = logging.FileHandler(log_path, mode='w')
fh.setLevel(logging.INFO)
fh.setFormatter(logging.Formatter('%(asctime)s %(levelname)s %(name)s: %(message)s'))
root = logging.getLogger(); root.addHandler(fh); root.setLevel(logging.INFO)

try:
    build_model(asset, out_dir)
    root.info('BUILD SUCCEEDED -> %s', out_dir)
    print('\nDONE -> model artifacts in', out_dir)
    print(sorted(os.listdir(out_dir)))
except Exception as e:
    root.error('BUILD FAILED: %s\n%s', e, traceback.format_exc())
    print('BUILD FAILED -- see log:', log_path)
    raise
finally:
    root.removeHandler(fh); fh.close()
    print('log saved ->', log_path)
# Out:
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# parsing model-builder asset
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
#
# WARNING:py.warnings:Passing 'use_legacy_dataset=True' to get the legacy behaviour is deprecated as of pyarrow 11.0.0, and the legacy implementation will be removed in a future version.
# Configuring model builder
# WARNING:zaml.artifact_engine.logger:fold_valid is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:target_spec is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:enforce_artifact_validation is given but is not an expected input.
# WARNING:zaml.artifact_engine.logger:base_features is given but is not an expected input.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_asset>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <input_data>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <monotonic_constraints_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <monotonic_constraints_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <add_default_monotonic_constraints>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <add_default_monotonic_constraints>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <fe_version>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <data_split>...
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <train_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <train_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <test_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <test_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <n_tiers>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <n_tiers>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <zest_score_mapping>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <zest_score_mapping>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <feature_definition_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <feature_definition_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <key_factor_mapping_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <value_based_key_factor_mapping_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <value_based_key_factor_mapping_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_app>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_app>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_data>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_data>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_target>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_target>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <valid_sample_weight>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <valid_sample_weight>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <exclusion_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <exclusion_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <bivariate_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <bivariate_fe_instructions>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Executing InputArtifact <pipeline_factory>...
# INFO:zaml.artifact_engine.logger:Executing InputAssetArtifact <asset>...
# INFO:zaml.artifact_engine.logger:Finished <asset>, total time spent: 0:00:00.000192
# INFO:zaml.artifact_engine.logger:Executing Versions <versions>...
# building model
# INFO:zaml.artifact_engine.logger:Finished <versions>, total time spent: 0:00:04.428972
# INFO:zaml.artifact_engine.logger:Executing MonotonicConstraintsListParser <parsed_monotonic_constraints_list>...
# INFO:zaml.artifact_engine.logger:Finished <parsed_monotonic_constraints_list>, total time spent: 0:00:00.945804
# INFO:zaml.artifact_engine.logger:Executing SplitterArtifact <splitter>...
# INFO:zaml.artifact_engine.logger:Finished <splitter>, total time spent: 0:00:00.000478
# INFO:zaml.artifact_engine.logger:Executing DataArtifact <data>...
# INFO:zaml.artifact_engine.logger:Finished <data>, total time spent: 0:00:00.000219
# INFO:zaml.artifact_engine.logger:Executing ExclusionListParser <parsed_exclusion_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <parsed_exclusion_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Finished <parsed_exclusion_list>, total time spent: 0:00:00.000388
# INFO:zaml.artifact_engine.logger:Executing BivariateFeParser <parsed_biv_fe_instructions>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <parsed_biv_fe_instructions>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Finished <parsed_biv_fe_instructions>, total time spent: 0:00:00.000370
# INFO:zaml.artifact_engine.logger:Executing NeutralizationListParser <parsed_neutralization_list>...
# INFO:zaml.artifact_engine.logger:Not all required inputs are available for optional artifact <parsed_neutralization_list>, thus it will be omitted.
# INFO:zaml.artifact_engine.logger:Finished <parsed_neutralization_list>, total time spent: 0:00:00.000980
# INFO:zaml.artifact_engine.logger:Executing SeriesArtifact <target>...
# INFO:zaml.artifact_engine.logger:Finished <target>, total time spent: 0:00:00.351311
# INFO:zaml.artifact_engine.logger:Executing AppArtifact <app>...
# INFO:zaml.artifact_engine.logger:Finished <app>, total time spent: 0:00:01.862142
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryConfigArtifact <pipe_factory_config>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory_config>, total time spent: 0:00:00.000269
# INFO:zaml.artifact_engine.logger:Executing FitParamsArtifact <fit_params>...
# INFO:zaml.artifact_engine.logger:Finished <fit_params>, total time spent: 0:00:00.000227
# INFO:zaml.artifact_engine.logger:Executing DataDictGenerator <data_dict>...
# INFO:zaml.artifact_engine.logger:Finished <data_dict>, total time spent: 0:00:00.003010
# INFO:zaml.artifact_engine.logger:Executing CatMapGenerator <cat_map>...
# INFO:zaml.artifact_engine.logger:Finished <cat_map>, total time spent: 0:00:00.002806
# INFO:zaml.artifact_engine.logger:Executing AppDateSeries <app_date_series>...
# INFO:zaml.artifact_engine.logger:Finished <app_date_series>, total time spent: 0:00:00.009653
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_target_collection>...
# WARNING:py.warnings:Target has different length with app data.
#
# INFO:zaml.artifact_engine.logger:Finished <split_target_collection>, total time spent: 0:00:02.003989
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_app_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_app_collection>, total time spent: 0:00:02.375775
# INFO:zaml.artifact_engine.logger:Executing SplitDataCollectionArtifact <split_data_collection>...
# INFO:zaml.artifact_engine.logger:Finished <split_data_collection>, total time spent: 0:00:20.176701
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_target>...
# INFO:zaml.artifact_engine.logger:Finished <train_target>, total time spent: 0:00:00.000273
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_app>...
# INFO:zaml.artifact_engine.logger:Finished <train_app>, total time spent: 0:00:00.000215
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_target>...
# INFO:zaml.artifact_engine.logger:Finished <test_target>, total time spent: 0:00:00.000217
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_app>...
# INFO:zaml.artifact_engine.logger:Finished <test_app>, total time spent: 0:00:00.000212
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <train_data>...
# INFO:zaml.artifact_engine.logger:Finished <train_data>, total time spent: 0:00:00.000210
# INFO:zaml.artifact_engine.logger:Executing SplitDataArtifact <test_data>...
# INFO:zaml.artifact_engine.logger:Finished <test_data>, total time spent: 0:00:00.000206
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <train_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <train_data_summary>, total time spent: 0:00:05.421002
# INFO:zaml.artifact_engine.logger:Executing SplitDataSummary <test_data_summary>...
# INFO:zaml.artifact_engine.logger:Finished <test_data_summary>, total time spent: 0:00:05.436911
# INFO:zaml.artifact_engine.logger:Executing PipeFitter <pipeline_fitter>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 52
# Time spent: 0.058s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 1143
# Time spent: 0.124s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.327s
# -------------------------
# Name: trade FE
# Transformer type: EndtoEndFeatureEngine
# Number of features: 1143
# Time spent: 2.966s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 1143
# Time spent: 11.492s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 1143
# Time spent: 2.755s
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 1143
# Time spent: 25.648s
# INFO:zaml.artifact_engine.logger:Finished <pipeline_fitter>, total time spent: 0:07:15.221720
# INFO:zaml.artifact_engine.logger:Executing FittedPipeline <pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <pipeline>, total time spent: 0:00:00.000414
# INFO:zaml.artifact_engine.logger:Executing FitTimeInfoArtifact <fit_time_info>...
# INFO:zaml.artifact_engine.logger:Finished <fit_time_info>, total time spent: 0:00:00.000242
# INFO:zaml.artifact_engine.logger:Executing PipeFactoryArtifact <pipe_factory>...
# INFO:zaml.artifact_engine.logger:Finished <pipe_factory>, total time spent: 0:00:00.021154
# INFO:zaml.artifact_engine.logger:Executing FittedModel <model>...
# INFO:zaml.artifact_engine.logger:Finished <model>, total time spent: 0:00:00.000233
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <train_fe_data>...
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 52
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 1143
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.402s
# -------------------------
# Name: trade FE
# Transformer type: EndtoEndFeatureEngine
# Number of features: 1143
# Time spent: 2.920s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 1143
# Time spent: 11.328s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 1143
# Time spent: 2.685s
# INFO:zaml.artifact_engine.logger:Finished <train_fe_data>, total time spent: 0:00:38.783316
# INFO:zaml.artifact_engine.logger:Executing FeDataArtifact <test_fe_data>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 1143
# Time spent: 21.447s
# -------------------------
# Name: app
# Transformer type: None
# Number of features: 52
# Time spent: 0.000s
# -------------------------
# Name: trade
# Transformer type: None
# Number of features: 1143
# Time spent: 0.000s
# -------------------------
# Name: app FE
# Transformer type: OneToOneEngine
# Number of features: 0
# Time spent: 0.392s
# -------------------------
# Name: trade FE
# Transformer type: EndtoEndFeatureEngine
# Number of features: 1143
# Time spent: 2.824s
# -------------------------
# Name: Merge data
# Transformer type: Concat
# Number of features: 1143
# Time spent: 11.357s
# -------------------------
# Name: LevelSelection
# Transformer type: LevelSelection
# Number of features: 1143
# Time spent: 2.748s
# INFO:zaml.artifact_engine.logger:Finished <test_fe_data>, total time spent: 0:00:39.273077
# INFO:zaml.artifact_engine.logger:Executing StaticAssetArtifact <static_asset>...
# INFO:zaml.artifact_engine.logger:Finished <static_asset>, total time spent: 0:00:00.197330
# INFO:zaml.artifact_engine.logger:Executing TrainHistoryArtifact <train_history>...
# INFO:zaml.artifact_engine.logger:Finished <train_history>, total time spent: 0:00:00.000266
# INFO:zaml.artifact_engine.logger:Executing BestModelParamsArtifact <best_model_params>...
# INFO:zaml.artifact_engine.logger:Finished <best_model_params>, total time spent: 0:00:00.000216
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <train_scores>...
# -------------------------
# Name: FillNA
# Transformer type: FillNA
# Number of features: 1143
# Time spent: 21.898s
# INFO:zaml.artifact_engine.logger:Finished <train_scores>, total time spent: 0:00:08.645070
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <train_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_scores>, total time spent: 0:00:00.000304
# INFO:zaml.artifact_engine.logger:Executing ScoresArtifact <test_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_scores>, total time spent: 0:00:08.450726
# INFO:zaml.artifact_engine.logger:Executing SubmodelScoresArtifact <test_submodel_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_scores>, total time spent: 0:00:00.000292
# INFO:zaml.artifact_engine.logger:Executing CalibrationObjectArtifact <calibration_object>...
# INFO:zaml.artifact_engine.logger:Finished <calibration_object>, total time spent: 0:00:11.306384
# INFO:zaml.artifact_engine.logger:Executing FeatureDefinition <feature_definition>...
# INFO:zaml.artifact_engine.logger:Finished <feature_definition>, total time spent: 0:00:00.073473
# INFO:zaml.artifact_engine.logger:Executing KeyFactorMapping <key_factors_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <key_factors_mapping>, total time spent: 0:00:00.001261
# INFO:zaml.artifact_engine.logger:Executing ValueBasedKeyFactorMapping <value_based_key_factor_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <value_based_key_factor_mapping>, total time spent: 0:00:00.000992
# INFO:zaml.artifact_engine.logger:Executing FeatureImportanceArtifact <feature_importance>...
# WARNING:py.warnings:Downsampling reference population to 3000 rows for Interventional Shapley
#
# WARNING:py.warnings:Downsampling explain population to 3000 rows for Interventional Shapley
#
# INFO:zaml.artifact_engine.logger:Finished <feature_importance>, total time spent: 0:00:28.308047
# INFO:zaml.artifact_engine.logger:Executing SubmodelFeatureImportanceArtifact <submodel_feature_importance>...
# INFO:zaml.artifact_engine.logger:Finished <submodel_feature_importance>, total time spent: 0:00:00.000304
# INFO:zaml.artifact_engine.logger:Executing ModelStrategy <model_strategy>...
# INFO:zaml.artifact_engine.logger:Finished <model_strategy>, total time spent: 0:00:00.000231
# INFO:zaml.artifact_engine.logger:Executing MRMPipeline <mrm_pipeline>...
# INFO:zaml.artifact_engine.logger:Finished <mrm_pipeline>, total time spent: 0:00:00.074324
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_auc>, total time spent: 0:00:02.362613
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <train_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_ks>, total time spent: 0:00:02.338581
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_auc>, total time spent: 0:00:00.000278
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <train_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <train_submodel_ks>, total time spent: 0:00:00.000232
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_auc>, total time spent: 0:00:02.313171
# INFO:zaml.artifact_engine.logger:Executing PerformanceArtifact <test_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_ks>, total time spent: 0:00:02.357303
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_auc>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_auc>, total time spent: 0:00:00.000283
# INFO:zaml.artifact_engine.logger:Executing SubmodelPerformanceArtifact <test_submodel_ks>...
# INFO:zaml.artifact_engine.logger:Finished <test_submodel_ks>, total time spent: 0:00:00.000237
# INFO:zaml.artifact_engine.logger:Executing CalibrationMapping <score_recalibration_mapping>...
# INFO:zaml.artifact_engine.logger:Finished <score_recalibration_mapping>, total time spent: 0:00:00.135886
# INFO:zaml.artifact_engine.logger:Executing TopFeaturesArtifact <top_features>...
# INFO:zaml.artifact_engine.logger:Finished <top_features>, total time spent: 0:00:00.003454
# INFO:zaml.artifact_engine.logger:Executing KeepFeatures <keep_features>...
# INFO:zaml.artifact_engine.logger:Finished <keep_features>, total time spent: 0:00:00.004254
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <train_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <train_zest_scores>, total time spent: 0:00:00.337715
# INFO:zaml.artifact_engine.logger:Executing SplitCalibratedScores <test_zest_scores>...
# INFO:zaml.artifact_engine.logger:Finished <test_zest_scores>, total time spent: 0:00:00.345094
# ERROR:zaml.artifact_engine.logger:`artifacts_pool` is not empty after a traversal. Remaining items are ['fold_valid', 'target_spec', 'enforce_artifact_validation', 'base_features'].
# INFO:root:BUILD SUCCEEDED -> /home/jag/payment-processor-research/payment_processing_research_data/models/model_new_deep
# DONE -> model artifacts in /home/jag/payment-processor-research/payment_processing_research_data/models/model_new_deep
# ['artifact_manifest.json', 'asset.json', 'best_model_params.json', 'build_model_new_deep.log', 'calibration_object.obj', 'feature_definition.parquet', 'feature_importance.parquet', 'fit_time_info.json', 'keep_features.json', 'key_factors_mapping.json', 'model.obj', 'model_strategy.json', 'mrm_pipeline.obj', 'parsed_monotonic_constraints_list.json', 'pipeline.obj', 'score_recalibration_mapping.json', 'splitter.obj', 'static_asset.json', 'test_app.parquet', 'test_auc.json', 'test_data_summary.json', 'test_fe_data.parquet', 'test_ks.json', 'test_scores.parquet', 'test_target.parquet', 'test_zest_scores.parquet', 'top_features.parquet', 'train_app.parquet', 'train_auc.json', 'train_data_summary.json', 'train_fe_data.parquet', 'train_history.json', 'train_ks.json', 'train_scores.parquet', 'train_target.parquet', 'train_zest_scores.parquet', 'value_based_key_factor_mapping.json', 'versions.json']
# log saved -> /home/jag/payment-processor-research/payment_processing_research_data/models/model_new_deep/build_model_new_deep.log
