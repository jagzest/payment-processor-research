# %% [markdown]
# # PrepareData -- Transunion / Test / OLD
#
# Split out from the original `PrepareDataOldMethod.ipynb` so this specific
# (bureau, split, method) combo runs independently with its own log file.
#
# **Why split:** the combined notebook finished `equifax/train` and `experian/train`
# (both phases) for both methods, then stalled inside `transunion/train` Phase 1
# (NEW stopped at chunk 463/534, OLD at 444/534). Splitting per (bureau, split,
# method) means each combo can be restarted on its own without re-running the
# already-done pieces, and each run has its own log.
#
# **This notebook:** runs the **OLD** aggregator over `transunion` / `test` only.
#
# The first thing it does is **clear `normalized_old/` and `processed_old/`
# for this (bureau, split)** so a half-finished run doesn't leak into the new run.
#
# **Outputs:**
# - `payment_processing_research_data/transunion/test/normalized_old/part-NNNNN.parquet`
# - `payment_processing_research_data/transunion/test/processed_old/part-NNN.parquet`
# - Log: `<cwd>/process_transunion_test_OLD.log`

# %%
# %pip install feature-engine-parts

# %%
# %pip install model-engine

# %%
import model_engine, feature_engine_parts
print('model_engine        :', model_engine.__file__)
print('feature_engine_parts:', feature_engine_parts.__file__)
# OLD method uses upstream feature_engine_parts (no missing_data_chars kwarg).
# Out:
# model_engine        : /home/jag/.local/lib/python3.10/site-packages/model_engine/__init__.py
# feature_engine_parts: /home/jag/.local/lib/python3.10/site-packages/feature_engine_parts/__init__.py

# %%
from model_engine.assets.utils import load_asset
asset = load_asset('transunion/TU4R/fe2/trade.json')
agg_step = next(s for s in asset['preprocess'] if s['type'] == 'PaymentPatternsAggregatorV2')
print('aggregator params keys:', sorted(agg_step['params'].keys()))
# OLD aggregator (upstream) doesn't accept missing_data_chars -- strip it
# defensively in case the asset on disk is the new-shape one.
for s in asset['preprocess']:
    if s['type'] == 'PaymentPatternsAggregatorV2':
        removed = s['params'].pop('missing_data_chars', None)
        if removed is not None:
            print('stripped top-level missing_data_chars =', removed)
# Out:
# aggregator params keys: ['payment_patterns', 'report_date']

# %%
import gc, os, sys, warnings
from pathlib import Path
import pandas as pd

from model_engine.feature_engine_V2.listed_objects_engines import MapperV2, PreprocessorV2
from model_engine.feature_engine_V2.feature_engine    import AggregationEngine
from configs import TRANSUNION, unmapped_dir, normalized_dir_old, processed_dir_old

warnings.filterwarnings('ignore')

BUREAU = TRANSUNION
SPLIT = 'test'
N_BUCKETS = 100

mapper       = MapperV2(api=asset['mapping'])
preprocessor = PreprocessorV2(api=asset['preprocess'])
agg_asset    = load_asset('aggregation/fe2/trade.json')
agg_eng      = AggregationEngine(asset=agg_asset, table_name='trade')
print(f'MapperV2 ({len(asset["mapping"])} steps) + PreprocessorV2 ({len(asset["preprocess"])} steps) + AggregationEngine ready')
# Out:
# MapperV2 (28 steps) + PreprocessorV2 (97 steps) + AggregationEngine ready

# %%
class _Tee:
    def __init__(self, *streams):
        self.streams = streams
    def write(self, data):
        for s in self.streams:
            try:
                s.write(data)
                s.flush()
            except Exception:
                pass
    def flush(self):
        for s in self.streams:
            try: s.flush()
            except Exception: pass

def clear_dir(d):
    d = Path(d)
    if d.exists():
        for f in d.glob('*'):
            if f.is_file():
                f.unlink()
    d.mkdir(parents=True, exist_ok=True)

def process_one():
    cfg      = BUREAU
    bureau   = cfg['bureau']
    split    = SPLIT
    in_dir   = Path(unmapped_dir(cfg, split))
    norm_dir = Path(normalized_dir_old(cfg, split))
    proc_dir = Path(processed_dir_old(cfg, split))

    log_path = Path(os.getcwd()) / f'process_{bureau}_{split}_OLD.log'
    original_stdout = sys.stdout
    with open(log_path, 'w', buffering=1) as log_file:
        sys.stdout = _Tee(original_stdout, log_file)
        try:
            print(f'(logging to {log_path})')
            print(f'\n##### {bureau}/{split} / OLD #####')

            parts = sorted(in_dir.glob('part-*.parquet')) if in_dir.exists() else []
            if not parts:
                print(f'MISSING unmapped chunks at {in_dir}  -- run save_unmapped_data.ipynb first')
                return

            print(f'clearing normalized + processed dirs first (idempotent)')
            print(f'  rm {norm_dir}/*')
            print(f'  rm {proc_dir}/*')
            clear_dir(norm_dir)
            clear_dir(proc_dir)

            # PHASE 1 -- map + preprocess in row chunks
            print(f'\nphase 1: map + preprocess ({len(parts)} chunks) -> {norm_dir}')
            for i, in_path in enumerate(parts):
                chunk      = pd.read_parquet(in_path)
                mapped     = mapper.transform(chunk)
                normalized = preprocessor.transform(mapped)
                out_path   = norm_dir / f'part-{i:05d}.parquet'
                normalized.to_parquet(out_path, index=False)
                print(f'  saved {i + 1}/{len(parts)} normalized -> {out_path}')
                del chunk, mapped, normalized
                gc.collect()

            # PHASE 2 -- aggregate per ZEST_KEY hash bucket
            print(f'\nphase 2: load full normalized, split into {N_BUCKETS} ZEST_KEY groups -> {proc_dir}')
            df = pd.read_parquet(norm_dir)
            print(f'  loaded {len(df):,} normalized rows')
            df['_bucket'] = (
                pd.util.hash_pandas_object(df['ZEST_KEY'], index=False) % N_BUCKETS
            ).astype('int16')

            total_rows = 0
            for b in range(N_BUCKETS):
                sub = df[df['_bucket'] == b].drop(columns='_bucket')
                if not len(sub):
                    continue
                processed = agg_eng.transform(sub)
                out_path = proc_dir / f'part-{b:03d}.parquet'
                processed.to_parquet(out_path, index=False)
                total_rows += len(processed)
                print(f'  saved group {b + 1}/{N_BUCKETS} processed ({total_rows:,} ZEST_KEYs so far) -> {out_path}')
                del sub, processed
                gc.collect()

            del df
            gc.collect()
            print(f'\ndone: {len(parts)} normalized chunks, {N_BUCKETS} processed groups, {total_rows:,} ZEST_KEYs')
        finally:
            sys.stdout = original_stdout
    print(f'process_one() done. Log saved to {log_path}')

process_one()
# Out:
# (logging to /home/jag/payment-processor-research/process_transunion_test_OLD.log)
#
# ##### transunion/test / OLD #####
# clearing normalized + processed dirs first (idempotent)
#   rm /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/*
#   rm /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/*
#
# phase 1: map + preprocess (445 chunks) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_
445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00286.parquet
#   saved 288/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00287.parquet
#   saved 289/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00288.parquet
#   saved 290/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00289.parquet
#   saved 291/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00290.parquet
#   saved 292/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00291.parquet
#   saved 293/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00292.parquet
#   saved 294/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00293.parquet
#   saved 295/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00294.parquet
#   saved 296/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00295.parquet
#   saved 297/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00296.parquet
#   saved 298/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00297.parquet
#   saved 299/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00298.parquet
#   saved 300/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00299.parquet
#   saved 301/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00300.parquet
#   saved 302/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00301.parquet
#   saved 303/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00302.parquet
#   saved 304/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00303.parquet
#   saved 305/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00304.parquet
#   saved 306/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00305.parquet
#   saved 307/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00306.parquet
#   saved 308/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00307.parquet
#   saved 309/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00308.parquet
#   saved 310/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00309.parquet
#   saved 311/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00310.parquet
#   saved 312/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00311.parquet
#   saved 313/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00312.parquet
#   saved 314/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00313.parquet
#   saved 315/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00314.parquet
#   saved 316/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00315.parquet
#   saved 317/445 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/normalized_old/part-00316.parquet
# ...
#   saved group 13/100 processed (302,892 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-012.parquet
#   saved group 14/100 processed (326,173 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-013.parquet
#   saved group 15/100 processed (349,500 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-014.parquet
#   saved group 16/100 processed (372,743 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-015.parquet
#   saved group 17/100 processed (396,166 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-016.parquet
#   saved group 18/100 processed (419,585 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-017.parquet
#   saved group 19/100 processed (442,559 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-018.parquet
#   saved group 20/100 processed (465,839 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-019.parquet
#   saved group 21/100 processed (489,020 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-020.parquet
#   saved group 22/100 processed (512,588 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-021.parquet
#   saved group 23/100 processed (535,773 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-022.parquet
#   saved group 24/100 processed (559,166 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-023.parquet
#   saved group 25/100 processed (582,592 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-024.parquet
#   saved group 26/100 processed (606,045 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-025.parquet
#   saved group 27/100 processed (629,544 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-026.parquet
#   saved group 28/100 processed (652,770 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-027.parquet
#   saved group 29/100 processed (676,246 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-028.parquet
#   saved group 30/100 processed (699,659 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-029.parquet
#   saved group 31/100 processed (722,908 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-030.parquet
#   saved group 32/100 processed (746,357 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-031.parquet
#   saved group 33/100 processed (769,728 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-032.parquet
#   saved group 34/100 processed (793,018 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-033.parquet
#   saved group 35/100 processed (816,192 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-034.parquet
#   saved group 36/100 processed (839,560 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-035.parquet
#   saved group 37/100 processed (862,980 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-036.parquet
#   saved group 38/100 processed (886,124 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-037.parquet
#   saved group 39/100 processed (909,239 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-038.parquet
#   saved group 40/100 processed (932,491 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-039.parquet
#   saved group 41/100 processed (955,863 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-040.parquet
#   saved group 42/100 processed (979,305 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-041.parquet
#   saved group 43/100 processed (1,002,606 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-042.parquet
#   saved group 44/100 processed (1,025,821 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-043.parquet
#   saved group 45/100 processed (1,049,079 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-044.parquet
#   saved group 46/100 processed (1,072,445 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-045.parquet
#   saved group 47/100 processed (1,095,764 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-046.parquet
#   saved group 48/100 processed (1,119,062 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-047.parquet
#   saved group 49/100 processed (1,142,492 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-048.parquet
#   saved group 50/100 processed (1,165,828 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-049.parquet
#   saved group 51/100 processed (1,189,133 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-050.parquet
#   saved group 52/100 processed (1,212,396 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-051.parquet
#   saved group 53/100 processed (1,236,001 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-052.parquet
#   saved group 54/100 processed (1,259,399 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-053.parquet
#   saved group 55/100 processed (1,282,548 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-054.parquet
#   saved group 56/100 processed (1,305,465 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-055.parquet
#   saved group 57/100 processed (1,328,619 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-056.parquet
#   saved group 58/100 processed (1,351,846 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-057.parquet
#   saved group 59/100 processed (1,375,080 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-058.parquet
#   saved group 60/100 processed (1,398,345 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-059.parquet
#   saved group 61/100 processed (1,421,757 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-060.parquet
#   saved group 62/100 processed (1,445,295 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-061.parquet
#   saved group 63/100 processed (1,468,429 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-062.parquet
#   saved group 64/100 processed (1,491,583 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-063.parquet
#   saved group 65/100 processed (1,515,142 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-064.parquet
#   saved group 66/100 processed (1,538,371 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-065.parquet
#   saved group 67/100 processed (1,561,595 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-066.parquet
#   saved group 68/100 processed (1,585,373 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-067.parquet
#   saved group 69/100 processed (1,608,777 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-068.parquet
#   saved group 70/100 processed (1,632,161 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-069.parquet
#   saved group 71/100 processed (1,655,519 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-070.parquet
#   saved group 72/100 processed (1,678,784 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-071.parquet
#   saved group 73/100 processed (1,702,359 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-072.parquet
#   saved group 74/100 processed (1,725,536 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-073.parquet
#   saved group 75/100 processed (1,748,805 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-074.parquet
#   saved group 76/100 processed (1,772,133 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-075.parquet
#   saved group 77/100 processed (1,795,538 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-076.parquet
#   saved group 78/100 processed (1,818,687 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-077.parquet
#   saved group 79/100 processed (1,841,863 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-078.parquet
#   saved group 80/100 processed (1,865,095 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-079.parquet
#   saved group 81/100 processed (1,888,385 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-080.parquet
#   saved group 82/100 processed (1,911,994 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-081.parquet
#   saved group 83/100 processed (1,935,287 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-082.parquet
#   saved group 84/100 processed (1,958,448 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-083.parquet
#   saved group 85/100 processed (1,981,692 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-084.parquet
#   saved group 86/100 processed (2,004,998 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-085.parquet
#   saved group 87/100 processed (2,028,288 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-086.parquet
#   saved group 88/100 processed (2,051,661 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-087.parquet
#   saved group 89/100 processed (2,074,788 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-088.parquet
#   saved group 90/100 processed (2,097,880 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-089.parquet
#   saved group 91/100 processed (2,121,459 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-090.parquet
#   saved group 92/100 processed (2,144,591 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-091.parquet
#   saved group 93/100 processed (2,167,740 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-092.parquet
#   saved group 94/100 processed (2,190,813 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-093.parquet
#   saved group 95/100 processed (2,214,182 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-094.parquet
#   saved group 96/100 processed (2,237,569 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-095.parquet
#   saved group 97/100 processed (2,260,879 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-096.parquet
#   saved group 98/100 processed (2,284,110 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-097.parquet
#   saved group 99/100 processed (2,307,336 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-098.parquet
#   saved group 100/100 processed (2,330,710 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/transunion/test/processed_old/part-099.parquet
#
# done: 445 normalized chunks, 100 processed groups, 2,330,710 ZEST_KEYs
# process_one() done. Log saved to /home/jag/payment-processor-research/process_transunion_test_OLD.log
