# %% [markdown]
# # PrepareData -- Equifax / Test / OLD
#
# Split out from the original `PrepareDataOldMethod.ipynb` so this specific
# (bureau, split, method) combo runs independently with its own log file.
#
# **Why split:** the combined notebook finished `equifax/train` and `experian/train`
# (both phases) for both methods, then stalled inside `transunion/train` Phase 1
# (NEW stopped at chunk 463/534, OLD at 444/534). Splitting per (bureau, split,
# method) means each combo can be restarted on its own without re-running the
# already-done pieces, and each run has its own log.
#
# **This notebook:** runs the **OLD** aggregator over `equifax` / `test` only.
#
# The first thing it does is **clear `normalized_old/` and `processed_old/`
# for this (bureau, split)** so a half-finished run doesn't leak into the new run.
#
# **Outputs:**
# - `payment_processing_research_data/equifax/test/normalized_old/part-NNNNN.parquet`
# - `payment_processing_research_data/equifax/test/processed_old/part-NNN.parquet`
# - Log: `<cwd>/process_equifax_test_OLD.log`

# %%
# %pip install feature-engine-parts

# %%
# %pip install model-engine

# %%
import model_engine, feature_engine_parts
print('model_engine        :', model_engine.__file__)
print('feature_engine_parts:', feature_engine_parts.__file__)
# OLD method uses upstream feature_engine_parts (no missing_data_chars kwarg).
# Out:
# model_engine        : /home/jag/.local/lib/python3.10/site-packages/model_engine/__init__.py
# feature_engine_parts: /home/jag/.local/lib/python3.10/site-packages/feature_engine_parts/__init__.py

# %%
from model_engine.assets.utils import load_asset
asset = load_asset('equifax/cms_6/fe2/trade.json')
agg_step = next(s for s in asset['preprocess'] if s['type'] == 'PaymentPatternsAggregatorV2')
print('aggregator params keys:', sorted(agg_step['params'].keys()))
# OLD aggregator (upstream) doesn't accept missing_data_chars -- strip it
# defensively in case the asset on disk is the new-shape one.
for s in asset['preprocess']:
    if s['type'] == 'PaymentPatternsAggregatorV2':
        removed = s['params'].pop('missing_data_chars', None)
        if removed is not None:
            print('stripped top-level missing_data_chars =', removed)
# Out:
# aggregator params keys: ['payment_patterns', 'report_date']

# %%
import gc, os, sys, warnings
from pathlib import Path
import pandas as pd

from model_engine.feature_engine_V2.listed_objects_engines import MapperV2, PreprocessorV2
from model_engine.feature_engine_V2.feature_engine    import AggregationEngine
from configs import EQUIFAX, unmapped_dir, normalized_dir_old, processed_dir_old

warnings.filterwarnings('ignore')

BUREAU = EQUIFAX
SPLIT = 'test'
N_BUCKETS = 100

mapper       = MapperV2(api=asset['mapping'])
preprocessor = PreprocessorV2(api=asset['preprocess'])
agg_asset    = load_asset('aggregation/fe2/trade.json')
agg_eng      = AggregationEngine(asset=agg_asset, table_name='trade')
print(f'MapperV2 ({len(asset["mapping"])} steps) + PreprocessorV2 ({len(asset["preprocess"])} steps) + AggregationEngine ready')
# Out:
# MapperV2 (30 steps) + PreprocessorV2 (100 steps) + AggregationEngine ready

# %%
class _Tee:
    def __init__(self, *streams):
        self.streams = streams
    def write(self, data):
        for s in self.streams:
            try:
                s.write(data)
                s.flush()
            except Exception:
                pass
    def flush(self):
        for s in self.streams:
            try: s.flush()
            except Exception: pass

def clear_dir(d):
    d = Path(d)
    if d.exists():
        for f in d.glob('*'):
            if f.is_file():
                f.unlink()
    d.mkdir(parents=True, exist_ok=True)

def process_one():
    cfg      = BUREAU
    bureau   = cfg['bureau']
    split    = SPLIT
    in_dir   = Path(unmapped_dir(cfg, split))
    norm_dir = Path(normalized_dir_old(cfg, split))
    proc_dir = Path(processed_dir_old(cfg, split))

    log_path = Path(os.getcwd()) / f'process_{bureau}_{split}_OLD.log'
    original_stdout = sys.stdout
    with open(log_path, 'w', buffering=1) as log_file:
        sys.stdout = _Tee(original_stdout, log_file)
        try:
            print(f'(logging to {log_path})')
            print(f'\n##### {bureau}/{split} / OLD #####')

            parts = sorted(in_dir.glob('part-*.parquet')) if in_dir.exists() else []
            if not parts:
                print(f'MISSING unmapped chunks at {in_dir}  -- run save_unmapped_data.ipynb first')
                return

            print(f'clearing normalized + processed dirs first (idempotent)')
            print(f'  rm {norm_dir}/*')
            print(f'  rm {proc_dir}/*')
            clear_dir(norm_dir)
            clear_dir(proc_dir)

            # PHASE 1 -- map + preprocess in row chunks
            print(f'\nphase 1: map + preprocess ({len(parts)} chunks) -> {norm_dir}')
            for i, in_path in enumerate(parts):
                chunk      = pd.read_parquet(in_path)
                mapped     = mapper.transform(chunk)
                normalized = preprocessor.transform(mapped)
                out_path   = norm_dir / f'part-{i:05d}.parquet'
                normalized.to_parquet(out_path, index=False)
                print(f'  saved {i + 1}/{len(parts)} normalized -> {out_path}')
                del chunk, mapped, normalized
                gc.collect()

            # PHASE 2 -- aggregate per ZEST_KEY hash bucket
            print(f'\nphase 2: load full normalized, split into {N_BUCKETS} ZEST_KEY groups -> {proc_dir}')
            df = pd.read_parquet(norm_dir)
            print(f'  loaded {len(df):,} normalized rows')
            df['_bucket'] = (
                pd.util.hash_pandas_object(df['ZEST_KEY'], index=False) % N_BUCKETS
            ).astype('int16')

            total_rows = 0
            for b in range(N_BUCKETS):
                sub = df[df['_bucket'] == b].drop(columns='_bucket')
                if not len(sub):
                    continue
                processed = agg_eng.transform(sub)
                out_path = proc_dir / f'part-{b:03d}.parquet'
                processed.to_parquet(out_path, index=False)
                total_rows += len(processed)
                print(f'  saved group {b + 1}/{N_BUCKETS} processed ({total_rows:,} ZEST_KEYs so far) -> {out_path}')
                del sub, processed
                gc.collect()

            del df
            gc.collect()
            print(f'\ndone: {len(parts)} normalized chunks, {N_BUCKETS} processed groups, {total_rows:,} ZEST_KEYs')
        finally:
            sys.stdout = original_stdout
    print(f'process_one() done. Log saved to {log_path}')

process_one()
# Out:
# (logging to /home/jag/payment-processor-research/process_equifax_test_OLD.log)
#
# ##### equifax/test / OLD #####
# clearing normalized + processed dirs first (idempotent)
#   rm /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/*
#   rm /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/*
#
# phase 1: map + preprocess (552 chunks) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old
#   saved 1/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00000.parquet
#   saved 2/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00001.parquet
#   saved 3/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00002.parquet
#   saved 4/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00003.parquet
#   saved 5/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00004.parquet
#   saved 6/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00005.parquet
#   saved 7/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00006.parquet
#   saved 8/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00007.parquet
#   saved 9/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00008.parquet
#   saved 10/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00009.parquet
#   saved 11/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00010.parquet
#   saved 12/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00011.parquet
#   saved 13/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00012.parquet
#   saved 14/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00013.parquet
#   saved 15/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00014.parquet
#   saved 16/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00015.parquet
#   saved 17/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00016.parquet
#   saved 18/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00017.parquet
#   saved 19/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00018.parquet
#   saved 20/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00019.parquet
#   saved 21/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00020.parquet
#   saved 22/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00021.parquet
#   saved 23/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00022.parquet
#   saved 24/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00023.parquet
#   saved 25/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00024.parquet
#   saved 26/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00025.parquet
#   saved 27/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-
552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00543.parquet
#   saved 545/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00544.parquet
#   saved 546/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00545.parquet
#   saved 547/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00546.parquet
#   saved 548/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00547.parquet
#   saved 549/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00548.parquet
#   saved 550/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00549.parquet
#   saved 551/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00550.parquet
#   saved 552/552 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/normalized_old/part-00551.parquet
#
# phase 2: load full normalized, split into 100 ZEST_KEY groups -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old
#   loaded 53,212,365 normalized rows
#   saved group 1/100 processed (25,902 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-000.parquet
#   saved group 2/100 processed (51,688 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-001.parquet
#   saved group 3/100 processed (77,769 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-002.parquet
#   saved group 4/100 processed (104,008 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-003.parquet
#   saved group 5/100 processed (129,806 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-004.parquet
#   saved group 6/100 processed (155,669 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-005.parquet
#   saved group 7/100 processed (181,500 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-006.parquet
#   saved group 8/100 processed (207,058 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-007.parquet
#   saved group 9/100 processed (233,012 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-008.parquet
#   saved group 10/100 processed (259,009 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-009.parquet
#   saved group 11/100 processed (284,827 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-010.parquet
#   saved group 12/100 processed (310,479 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-011.parquet
#   saved group 13/100 processed (336,060 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-012.parquet
#   saved group 14/100 processed (361,803 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-013.parquet
#   saved group 15/100 processed (387,427 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-014.parquet
#   saved group 16/100 processed (413,206 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-015.parquet
#   saved group 17/100 processed (438,918 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-016.parquet
#   saved group 18/100 processed (464,998 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-017.parquet
#   saved group 19/100 processed (490,568 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-018.parquet
#   saved group 20/100 processed (516,440 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-019.parquet
#   saved group 21/100 processed (542,407 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-020.parquet
#   saved group 22/100 processed (567,775 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-021.parquet
#   saved group 23/100 processed (593,641 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-022.parquet
#   saved group 24/100 processed (619,331 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-023.parquet
#   saved group 25/100 processed (645,306 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-024.parquet
#   saved group 26/100 processed (670,952 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-025.parquet
#   saved group 27/100 processed (696,914 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-026.parquet
#   saved group 28/100 processed (722,883 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-027.parquet
#   saved group 29/100 processed (748,833 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-028.parquet
#   saved group 30/100 processed (774,718 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-029.parquet
#   saved group 31/100 processed (800,446 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-030.parquet
#   saved group 32/100 processed (826,168 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-031.parquet
#   saved group 33/100 processed (852,057 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-032.parquet
#   saved group 34/100 processed (877,979 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-033.parquet
#   saved group 35/100 processed (904,146 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-034.parquet
#   saved group 36/100 processed (930,129 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-035.parquet
#   saved group 37/100 processed (955,818 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-036.parquet
#   saved group 38/100 processed (981,636 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-037.parquet
#   saved group 39/100 processed (1,007,390 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-038.parquet
#   saved group 40/100 processed (1,033,474 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-039.parquet
#   saved group 41/100 processed (1,059,313 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-040.parquet
#   saved group 42/100 processed (1,085,262 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-041.parquet
#   saved group 43/100 processed (1,110,945 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-042.parquet
#   saved group 44/100 processed (1,136,758 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-043.parquet
#   saved group 45/100 processed (1,162,763 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-044.parquet
#   saved group 46/100 processed (1,188,441 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-045.parquet
#   saved group 47/100 processed (1,214,518 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-046.parquet
#   saved group 48/100 processed (1,240,311 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-047.parquet
#   saved group 49/100 processed (1,266,037 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-048.parquet
#   saved group 50/100 processed (1,291,911 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-049.parquet
#   saved group 51/100 processed (1,317,612 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-050.parquet
#   saved group 52/100 processed (1,343,176 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-051.parquet
#   saved group 53/100 processed (1,369,021 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-052.parquet
#   saved group 54/100 processed (1,394,943 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-053.parquet
#   saved group 55/100 processed (1,421,303 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-054.parquet
#   saved group 56/100 processed (1,446,926 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/test/processed_old/part-055.parquet
