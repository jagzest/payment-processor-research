# %% [markdown]
# # PrepareData -- Equifax / Valid / NEW
#
# Split out from the original `PrepareDataNewMethod.ipynb` so this specific
# (bureau, split, method) combo runs independently with its own log file.
#
# **Why split:** the combined notebook finished `equifax/train` and `experian/train`
# (both phases) for both methods, then stalled inside `transunion/train` Phase 1
# (NEW stopped at chunk 463/534, OLD at 444/534). Splitting per (bureau, split,
# method) means each combo can be restarted on its own without re-running the
# already-done pieces, and each run has its own log.
#
# **This notebook:** runs the **NEW** aggregator over `equifax` / `valid` only.
#
# The first thing it does is **clear `normalized_new/` and `processed_new/`
# for this (bureau, split)** so a half-finished run doesn't leak into the new run.
#
# **Outputs:**
# - `payment_processing_research_data/equifax/valid/normalized_new/part-NNNNN.parquet`
# - `payment_processing_research_data/equifax/valid/processed_new/part-NNN.parquet`
# - Log: `<cwd>/process_equifax_valid_NEW.log`

# %%
# %pip install -e /home/jag/model-engine

# %%
# %pip install -e /home/jag/feature-engine-parts-processor-change

# %%
import sys
sys.path.insert(0, '/home/jag/feature-engine-parts-processor-change')
sys.path.insert(0, '/home/jag/model-engine')

import model_engine, feature_engine_parts
print('model_engine        :', model_engine.__file__)
print('feature_engine_parts:', feature_engine_parts.__file__)
# Sanity: both should resolve to /home/jag/... (the editable checkouts).
# Out:
# model_engine        : /home/jag/model-engine/model_engine/__init__.py
# feature_engine_parts: /home/jag/feature-engine-parts-processor-change/feature_engine_parts/__init__.py

# %%
from model_engine.assets.utils import load_asset
asset = load_asset('equifax/cms_6/fe2/trade.json')
agg_step = next(s for s in asset['preprocess'] if s['type'] == 'PaymentPatternsAggregatorV2')
print('aggregator params keys:', sorted(agg_step['params'].keys()))
assert 'missing_data_chars' in agg_step['params'], (
    'asset must have top-level missing_data_chars for the NEW aggregator. '
    'Check that model_engine is loading from /home/jag/model-engine/, not ~/.local/.')
print('missing_data_chars:', agg_step['params']['missing_data_chars'])
# Out:
# aggregator params keys: ['missing_data_chars', 'payment_patterns', 'report_date']
# missing_data_chars: ['*']

# %%
import gc, os, sys, warnings
from pathlib import Path
import pandas as pd

from model_engine.feature_engine_V2.listed_objects_engines import MapperV2, PreprocessorV2
from model_engine.feature_engine_V2.feature_engine    import AggregationEngine
from configs import EQUIFAX, unmapped_dir, normalized_dir_new, processed_dir_new

warnings.filterwarnings('ignore')

BUREAU = EQUIFAX
SPLIT = 'valid'
N_BUCKETS = 100

mapper       = MapperV2(api=asset['mapping'])
preprocessor = PreprocessorV2(api=asset['preprocess'])
agg_asset    = load_asset('aggregation/fe2/trade.json')
agg_eng      = AggregationEngine(asset=agg_asset, table_name='trade')
print(f'MapperV2 ({len(asset["mapping"])} steps) + PreprocessorV2 ({len(asset["preprocess"])} steps) + AggregationEngine ready')
# Out:
# MapperV2 (30 steps) + PreprocessorV2 (100 steps) + AggregationEngine ready

# %%
class _Tee:
    def __init__(self, *streams):
        self.streams = streams
    def write(self, data):
        for s in self.streams:
            try:
                s.write(data)
                s.flush()
            except Exception:
                pass
    def flush(self):
        for s in self.streams:
            try: s.flush()
            except Exception: pass

def clear_dir(d):
    d = Path(d)
    if d.exists():
        for f in d.glob('*'):
            if f.is_file():
                f.unlink()
    d.mkdir(parents=True, exist_ok=True)

def process_one():
    cfg      = BUREAU
    bureau   = cfg['bureau']
    split    = SPLIT
    in_dir   = Path(unmapped_dir(cfg, split))
    norm_dir = Path(normalized_dir_new(cfg, split))
    proc_dir = Path(processed_dir_new(cfg, split))

    log_path = Path(os.getcwd()) / f'process_{bureau}_{split}_NEW.log'
    original_stdout = sys.stdout
    with open(log_path, 'w', buffering=1) as log_file:
        sys.stdout = _Tee(original_stdout, log_file)
        try:
            print(f'(logging to {log_path})')
            print(f'\n##### {bureau}/{split} / NEW #####')

            parts = sorted(in_dir.glob('part-*.parquet')) if in_dir.exists() else []
            if not parts:
                print(f'MISSING unmapped chunks at {in_dir}  -- run save_unmapped_data.ipynb first')
                return

            print(f'clearing normalized + processed dirs first (idempotent)')
            print(f'  rm {norm_dir}/*')
            print(f'  rm {proc_dir}/*')
            clear_dir(norm_dir)
            clear_dir(proc_dir)

            # PHASE 1 -- map + preprocess in row chunks
            print(f'\nphase 1: map + preprocess ({len(parts)} chunks) -> {norm_dir}')
            for i, in_path in enumerate(parts):
                chunk      = pd.read_parquet(in_path)
                mapped     = mapper.transform(chunk)
                normalized = preprocessor.transform(mapped)
                out_path   = norm_dir / f'part-{i:05d}.parquet'
                normalized.to_parquet(out_path, index=False)
                print(f'  saved {i + 1}/{len(parts)} normalized -> {out_path}')
                del chunk, mapped, normalized
                gc.collect()

            # PHASE 2 -- aggregate per ZEST_KEY hash bucket
            print(f'\nphase 2: load full normalized, split into {N_BUCKETS} ZEST_KEY groups -> {proc_dir}')
            df = pd.read_parquet(norm_dir)
            print(f'  loaded {len(df):,} normalized rows')
            df['_bucket'] = (
                pd.util.hash_pandas_object(df['ZEST_KEY'], index=False) % N_BUCKETS
            ).astype('int16')

            total_rows = 0
            for b in range(N_BUCKETS):
                sub = df[df['_bucket'] == b].drop(columns='_bucket')
                if not len(sub):
                    continue
                processed = agg_eng.transform(sub)
                out_path = proc_dir / f'part-{b:03d}.parquet'
                processed.to_parquet(out_path, index=False)
                total_rows += len(processed)
                print(f'  saved group {b + 1}/{N_BUCKETS} processed ({total_rows:,} ZEST_KEYs so far) -> {out_path}')
                del sub, processed
                gc.collect()

            del df
            gc.collect()
            print(f'\ndone: {len(parts)} normalized chunks, {N_BUCKETS} processed groups, {total_rows:,} ZEST_KEYs')
        finally:
            sys.stdout = original_stdout
    print(f'process_one() done. Log saved to {log_path}')

process_one()
# Out:
# (logging to /home/jag/payment-processor-research/process_equifax_valid_NEW.log)
#
# ##### equifax/valid / NEW #####
# clearing normalized + processed dirs first (idempotent)
#   rm /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/*
#   rm /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new
596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00292.parquet
#   saved 294/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00293.parquet
#   saved 295/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00294.parquet
#   saved 296/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00295.parquet
#   saved 297/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00296.parquet
#   saved 298/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00297.parquet
#   saved 299/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00298.parquet
#   saved 300/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00299.parquet
#   saved 301/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00300.parquet
#   saved 302/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00301.parquet
#   saved 303/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00302.parquet
#   saved 304/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00303.parquet
#   saved 305/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00304.parquet
#   saved 306/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00305.parquet
#   saved 307/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00306.parquet
#   saved 308/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00307.parquet
#   saved 309/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00308.parquet
#   saved 310/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00309.parquet
#   saved 311/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00310.parquet
#   saved 312/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00311.parquet
#   saved 313/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00312.parquet
#   saved 314/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00313.parquet
#   saved 315/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00314.parquet
#   saved 316/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00315.parquet
#   saved 317/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00316.parquet
#   saved 318/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00317.parquet
#   saved 319/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00318.parquet
#   saved 320/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00319.parquet
#   saved 321/596 normalized -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/normalized_new/part-00320.parquet
# ...
#   saved group 12/100 processed (334,745 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-011.parquet
#   saved group 13/100 processed (362,658 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-012.parquet
#   saved group 14/100 processed (390,286 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-013.parquet
#   saved group 15/100 processed (418,149 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-014.parquet
#   saved group 16/100 processed (446,024 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-015.parquet
#   saved group 17/100 processed (473,756 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-016.parquet
#   saved group 18/100 processed (501,819 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-017.parquet
#   saved group 19/100 processed (529,547 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-018.parquet
#   saved group 20/100 processed (557,446 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-019.parquet
#   saved group 21/100 processed (585,486 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-020.parquet
#   saved group 22/100 processed (613,222 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-021.parquet
#   saved group 23/100 processed (641,221 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-022.parquet
#   saved group 24/100 processed (669,172 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-023.parquet
#   saved group 25/100 processed (696,778 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-024.parquet
#   saved group 26/100 processed (724,349 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-025.parquet
#   saved group 27/100 processed (752,322 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-026.parquet
#   saved group 28/100 processed (779,894 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-027.parquet
#   saved group 29/100 processed (807,463 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-028.parquet
#   saved group 30/100 processed (835,392 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-029.parquet
#   saved group 31/100 processed (862,945 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-030.parquet
#   saved group 32/100 processed (890,732 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-031.parquet
#   saved group 33/100 processed (918,473 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-032.parquet
#   saved group 34/100 processed (946,332 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-033.parquet
#   saved group 35/100 processed (974,296 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-034.parquet
#   saved group 36/100 processed (1,002,282 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-035.parquet
#   saved group 37/100 processed (1,030,068 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-036.parquet
#   saved group 38/100 processed (1,057,970 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-037.parquet
#   saved group 39/100 processed (1,085,873 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-038.parquet
#   saved group 40/100 processed (1,113,569 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-039.parquet
#   saved group 41/100 processed (1,141,412 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-040.parquet
#   saved group 42/100 processed (1,169,067 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-041.parquet
#   saved group 43/100 processed (1,196,743 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-042.parquet
#   saved group 44/100 processed (1,224,640 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-043.parquet
#   saved group 45/100 processed (1,252,362 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-044.parquet
#   saved group 46/100 processed (1,280,234 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-045.parquet
#   saved group 47/100 processed (1,307,967 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-046.parquet
#   saved group 48/100 processed (1,335,738 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-047.parquet
#   saved group 49/100 processed (1,363,568 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-048.parquet
#   saved group 50/100 processed (1,391,374 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-049.parquet
#   saved group 51/100 processed (1,419,153 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-050.parquet
#   saved group 52/100 processed (1,446,900 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-051.parquet
#   saved group 53/100 processed (1,474,910 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-052.parquet
#   saved group 54/100 processed (1,502,774 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-053.parquet
#   saved group 55/100 processed (1,530,631 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-054.parquet
#   saved group 56/100 processed (1,558,234 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-055.parquet
#   saved group 57/100 processed (1,586,242 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-056.parquet
#   saved group 58/100 processed (1,614,064 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-057.parquet
#   saved group 59/100 processed (1,642,010 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-058.parquet
#   saved group 60/100 processed (1,669,906 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-059.parquet
#   saved group 61/100 processed (1,697,927 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-060.parquet
#   saved group 62/100 processed (1,725,855 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-061.parquet
#   saved group 63/100 processed (1,753,552 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-062.parquet
#   saved group 64/100 processed (1,781,153 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-063.parquet
#   saved group 65/100 processed (1,808,922 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-064.parquet
#   saved group 66/100 processed (1,837,001 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-065.parquet
#   saved group 67/100 processed (1,864,620 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-066.parquet
#   saved group 68/100 processed (1,892,535 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-067.parquet
#   saved group 69/100 processed (1,920,308 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-068.parquet
#   saved group 70/100 processed (1,948,346 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-069.parquet
#   saved group 71/100 processed (1,976,280 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-070.parquet
#   saved group 72/100 processed (2,003,817 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-071.parquet
#   saved group 73/100 processed (2,031,566 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-072.parquet
#   saved group 74/100 processed (2,059,417 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-073.parquet
#   saved group 75/100 processed (2,087,302 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-074.parquet
#   saved group 76/100 processed (2,114,878 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-075.parquet
#   saved group 77/100 processed (2,142,549 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-076.parquet
#   saved group 78/100 processed (2,170,275 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-077.parquet
#   saved group 79/100 processed (2,197,993 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-078.parquet
#   saved group 80/100 processed (2,225,705 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-079.parquet
#   saved group 81/100 processed (2,253,389 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-080.parquet
#   saved group 82/100 processed (2,281,103 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-081.parquet
#   saved group 83/100 processed (2,309,038 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-082.parquet
#   saved group 84/100 processed (2,336,772 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-083.parquet
#   saved group 85/100 processed (2,364,622 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-084.parquet
#   saved group 86/100 processed (2,392,466 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-085.parquet
#   saved group 87/100 processed (2,419,880 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-086.parquet
#   saved group 88/100 processed (2,447,626 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-087.parquet
#   saved group 89/100 processed (2,475,409 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-088.parquet
#   saved group 90/100 processed (2,503,238 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-089.parquet
#   saved group 91/100 processed (2,531,048 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-090.parquet
#   saved group 92/100 processed (2,558,971 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-091.parquet
#   saved group 93/100 processed (2,587,154 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-092.parquet
#   saved group 94/100 processed (2,614,911 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-093.parquet
#   saved group 95/100 processed (2,642,744 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-094.parquet
#   saved group 96/100 processed (2,670,725 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-095.parquet
#   saved group 97/100 processed (2,698,441 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-096.parquet
#   saved group 98/100 processed (2,726,418 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-097.parquet
#   saved group 99/100 processed (2,754,545 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-098.parquet
#   saved group 100/100 processed (2,782,553 ZEST_KEYs so far) -> /home/jag/payment-processor-research/payment_processing_research_data/equifax/valid/processed_new/part-099.parquet
#
# done: 596 normalized chunks, 100 processed groups, 2,782,553 ZEST_KEYs
# process_one() done. Log saved to /home/jag/payment-processor-research/process_equifax_valid_NEW.log
